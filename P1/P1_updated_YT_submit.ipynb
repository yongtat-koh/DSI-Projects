# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# A) Participation rate of SAT is higher than ACT or vice versa
#
# B) Relationship of SAT and ACT scores

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:

# Numpy Library
import numpy as np

# from matplotlib import pyplot to plot graphs
import matplotlib.pyplot as plt

# Seaborn visualization library; based on matplotlib
import seaborn as sns

# from scipy library, import stats function to do statistical functions
import scipy.stats as stats

# Python Data Analysis Library
import pandas as pd

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Code:
sat_17_data = './data/sat_2017.csv'
act_17_data = './data/act_2017.csv'

#sat17 dataframe
sat17 = pd.read_csv(sat_17_data)

#act17 dataframe
act17 = pd.read_csv(act_17_data)

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
#Code:

# sat17 10 rows of dataframe
sat17[0:11]
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
#
#     Math  Total
# 0    572   1165
# 1    533   1080
# ...

# %%
# act17 10 rows of dataframe
act17[0:11]
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# ...

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %%
j = [b for b in sat17.State]
k = [a for a in act17.State]

# %%
#check which is the additional row
[x for x in k if x not in j]
# Out:
# ['National']

# %% [markdown]
# ### Answer:
#
# #### Definition of SAT taken from https://en.wikipedia.org/wiki/SAT
# The SAT is a standardized test widely used for college admissions in the United States. It was debuted by the College Board in 1926, its name and scoring have changed several times; originally called the Scholastic Aptitude Test, it was later called the Scholastic Assessment Test, then the SAT I: Reasoning Test, then the SAT Reasoning Test, then simply the SAT.
#
# The SAT is wholly owned, developed, and published by the College Board, a private, not-for-profit organization in the United States. The test is intended to assess students' readiness for college. The SAT was originally designed not to be aligned with high school curricula, but several adjustments were made for the version of the SAT introduced in 2016, and College Board president, David Coleman, has said that he also wanted to make the test reflect more closely what students learn in high school.
#
# Scores on the SAT range from 400 to 1600, combining test results from two 200-to-800-point sections: Mathematics, and Critical Reading and Writing.
#
# #### Definition of ACT taken from https://en.wikipedia.org/wiki/ACT_(test)
# The ACT is originally an abbreviation of American College Testing). It is a standardized test used for college admissions in the United States. It is currently administered by ACT, a nonprofit organization of the same name. The ACT test covers four academic skill areas: English, mathematics, reading, and science reasoning. It also offers an optional direct writing test. It is accepted by all four-year colleges and universities in the United States as well as more than 225 universities outside of the U.S.
#
# The main four ACT test sections are individually scored on a scale of 1–36, and a composite score (the rounded whole number average of the four sections) is provided.
#
# #### act_2017 database
# The total score for each subject is 1 to 36. The database contains the ACT scores for the 4 subjects across the States listed in USA in 2017.  The participation rate and average ACT score in each State and are recorded also. The national ACT scores for English, Math, Reading and Science, the average ACT score, and the national participation rate are recorded as well.
#
# #### sat_2017 database
# The total score for each is 200 to 800 points. The database contains the SAT scores for Evidence-Based Reading (ERW) and Math. It also contains the participation rate from each State and the total SAT score.
#
# The database does not have the national participation rate, national average score for ERW and Math, total of the national average score of ERW and Math.
#
# Whereas in the website https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/;
# The national average score for ERW is stated as 533, national average score for Math is stated as 527, the total for ERW and Math is stated as 1060. The national participation rate is stated as non-applicable and the total number of students that were tested is stated as 1,715,481.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# #### Answer:
# The database is incomplete for act_2017 database, as it does not have the the national participation rate, national average score for ERW and Math, total of the national average score of ERW and Math.
#
# The national average is important as it helps to give educators and students a yardstick on their standing to secure admission to a college in the USA.

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %%
sat17.apply(min)
# Out:
# State                                 Alabama
# Participation                             10%
# Evidence-Based Reading and Writing        482
# Math                                       52
# Total                                     950
# dtype: object

# %%
sat17.apply(max)
# Out:
# State                                 Wyoming
# Participation                             96%
# Evidence-Based Reading and Writing        644
# Math                                      651
# Total                                    1295
# dtype: object

# %%
sat17.mean()
# Out:
# Evidence-Based Reading and Writing     569.117647
# Math                                   547.627451
# Total                                 1126.098039
# dtype: float64

# %%
act17.apply(min)
# Out:
# State            Alabama
# Participation        60%
# English             16.3
# Math                  18
# Reading             18.1
# Science              2.3
# Composite           17.8
# dtype: object

# %%
act17.apply(max)
# Out:
# State            Wyoming
# Participation        98%
# English             25.5
# Math                25.3
# Reading               26
# Science             24.9
# Composite           25.5
# dtype: object

# %% [markdown]
# #### Answer:
# There are no obvious issues with the sat_2017 and act_2017 datasets.
#
# For sat 2017, the min score for ERW is 482, Math is 52, total 1295.
# For sat 2017, the max score for ERW is 644, Math is 651, total 950.
#
# For act 2017, the min score for English, Math, Reading, Science is 16.3, 18, 18.1, 2.3, 17.8 respectively.
# For act 2017, the max score for English, Math, Reading, Science is 25.5, 23.3, 26, 24.9, 25.5 respectively.
#
# The SAT scores are within the range of 200 to 800, and the total score is within range of 1600. The act scores are within the range of 1 to 36.
#
# Pandas is used to calculate the mean score for ERW and Math, which are 569 and 547 respectively. The mean total is 1126.
# When we compare to the reported values of from collegevine.com, where the national average for ERW is 533, national average score for Math is 527, the mean total is 1060, there is a slight difference in the results obtained, but the difference is small.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
#code
act17.tail()
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %% [markdown]
# There is an error in Wyoming composite.

# %%
#error fix
act17.at[51,'Composite'] = '20.2'

# %%
act17.tail(3)
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %%
# re-assign fixed act17 back to act17
act17 = act17

# %%
act17.tail(3)
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#code
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# #### Answer:
#
# The values for Participation columns, which records the participation rate in sat_2017 and act_2017 databases are saved as objects. For act_2017, the Composite column is saved as object.
#
# Participation rate should be in integers as they are intended to be percentage values.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
#code
# map lambda function to replace % in each entry in Participation for sat17
sat17['Participation'] = sat17['Participation'].map(lambda x: x.replace('%',""))

# %%
# set data type as float
sat17['Participation'] = sat17['Participation'].astype(float)

# %%
sat17['Participation'].head(3)
# Out:
# 0     5.0
# 1    38.0
# 2    30.0
# Name: Participation, dtype: float64

# %%
sat17[['Participation']].head(3)
# Out:
#    Participation
# 0            5.0
# 1           38.0
# 2           30.0

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %%
#code
# map lambda function to replace % in each entry in Participation for act17
act17['Participation'] = act17['Participation'].map(lambda x: x.replace('%',""))

# %%
# set data type as float in Participate for act17
act17['Participation'] = act17['Participation'].astype(float)

# %%
# set data type as float for Composite in act17
act17['Composite'] = act17['Composite'].astype(float)

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
#code
act17.Participation.dtype
# Out:
# dtype('float64')

# %%
sat17.Participation.dtype
# Out:
# dtype('float64')

# %%
act17.Composite.dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Code:
sat17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#code
# dictionaries for renaming columns in sat17 and act17 data
sat_17_new_columns_dict = {
        'State':'state',
        'Participation':'sat_2017_participation_percent',
        'Evidence-Based Reading and Writing':'sat_2017_erw',
        'Math':'sat_2017_math',
        'Total':'sat_2017_total',
    }

act_17_new_columns_dict = {
        'State':'state',
        'Participation':'act_2017_participation_percent',
        'English':'act_2017_avg_english',
        'Math':'act_2017_avg_math',
        'Reading':'act_2017_avg_reading',
        'Science':'act_2017_avg_science',
        'Composite':'act_2017_avg_composite',
    }

# %%
sat17_rename = sat17.rename(columns = sat_17_new_columns_dict)

# %%
act17_rename = act17.rename(columns = act_17_new_columns_dict)

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |state|object|ACT/SAT|name of the state|
# |act_2017_participation_percent|float|ACT|Based on the number of graduates in the state, the percentage who took *act* test.|
# |act_2017_avg_english|float|ACT|Each row in this column is the average *english* act score for each state.|
# |act_2017_avg_math|float|ACT|Each row in this column is the average *math* act score for each state.|
# |act_2017_avg_reading |float|ACT|Each row in this column is the average *reading* act score for each state.|
# |act_2017_avg_science|float|ACT|Each row in this column is the average *science* act score for each state.|
# |act_2017_avg_composite|float|ACT|Each row in this column is the average *composite* act score for each state. *Composite* is the *average* of eng, math, reading, science|
# |sat_2017_participation_percent|float|SAT|Based on the number of graduates in the state, the percentage who took *sat* test.|
# |sat_2017_erw|int|SAT|Each row in this column is the average *Evidence-Based Reading and Writing* sat score for each state.|
# |sat_2017_math|int|SAT|Each row in this column is the average *math* sat score for each state.|
# |sat_2017_total|int|SAT|Each row in this column is the average *total* sat score for each state.|
# |act_2018_participation_percent|float|ACT|Based on the number of graduates in the state, the percentage who took *act* test.|
# |act_2018_avg_composite|float|ACT|Each row in this column is the average *composite* act score for each state. *Composite* is the *average* of eng, math, reading, science|
# |act_2018_avg_english|float|ACT|Each row in this column is the average *english* act score for each state.|
# |act_2018_avg_math|float|ACT|Each row in this column is the average *math* act score for each state.|
# |act_2018_avg_reading |float|ACT|Each row in this column is the average *reading* act score for each state.|
# |act_2018_avg_science|float|ACT|Each row in this column is the average *science* act score for each state.|
# sat_2018_participation_percent|float|SAT|Based on the number of graduates in the state, the percentage who took *sat* test.|
# |sat_2018_erw|int|SAT|Each row in this column is the average *Evidence-Based Reading and Writing* sat score for each state.|
# |sat_2018_math|int|SAT|Each row in this column is the average *math* sat score for each state.|
# |sat_2018_total|int|SAT|Each row in this column is the average *total* sat score for each state.|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
#code
# drop 'National' row from act17 data
act17_rename_drop_Nat = act17_rename.drop(0).reset_index(drop = True)

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
sat17_rename.shape
# Out:
# (51, 5)

# %%
act17_rename_drop_Nat.shape
# Out:
# (51, 7)

# %%
#Code:
# merge sat17 and act17
satact17_join = pd.merge(act17_rename_drop_Nat, sat17_rename, on = 'state')

# %%
satact17_join.shape
# Out:
# (51, 11)

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#code
# export and save merged file as a new file
satact17_join.to_csv('combined_2017.csv', index = False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Links to the 2018 ACT and SAT data are provided in the README. These data live in PDFs, and so you'll get to enjoy practicing some *manual* data collection. Save these data as a CSV in your `data` directory, and import, explore, and clean these data in the same way you did above. **Make sure you comment on your steps so it is clear *why* you are doing each process**.

# %%
sat18_file = './data/sat_2018.csv'
act18_file = './data/act_2018_updated.csv'
combo_2017 = './combined_2017.csv'

# import data
sat18 = pd.read_csv(sat18_file)
act18 = pd.read_csv(act18_file)
combined_2017 = pd.read_csv(combo_2017)

# %%
# replace % with '' in sat18.Participation
sat18['Participation'] = sat18['Participation'].map(lambda x: x.replace('%',""))

# %%
# set data as float
sat18['Participation'] = sat18['Participation'].astype(float)

# %%
#check data
sat18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     float64
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 2.1+ KB

# %%
# set data as float
act18['Percentage of Students Tested'] = act18['Percentage of Students Tested'].astype(float)

# %%
#check data
act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          51 non-null     object
#  1   Percentage of Students Tested  51 non-null     float64
#  2   Average Composite Score        51 non-null     float64
#  3   Average English Score          51 non-null     float64
#  4   Average Math Score             51 non-null     float64
#  5   Average Reading Score          51 non-null     float64
#  6   Average Science Score          51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
#rename columns in sat_2018 and act_2018
sat_18_new_columns_dict = {
        'State':'state',
        'Participation':'sat_2018_participation_percent',
        'Evidence-Based Reading and Writing':'sat_2018_erw',
        'Math':'sat_2018_math',
        'Total':'sat_2018_total',
    }

act_18_new_columns_dict = {
        'State':'state',
        'Percentage of Students Tested':'act_2018_participation_percent',
        'Average Composite Score':'act_2018_avg_composite',
        'Average English Score':'act_2018_avg_english',
        'Average Math Score':'act_2018_avg_math',
        'Average Reading Score':'act_2018_avg_reading',
        'Average Science Score':'act_2018_avg_science',
    }

# %%
sat18_rename = sat18.rename(columns = sat_18_new_columns_dict)

# %%
act18_rename = act18.rename(columns = act_18_new_columns_dict)

# %%
sat18_rename.shape
# Out:
# (51, 5)

# %%
act18_rename.shape
# Out:
# (51, 7)

# %%
# merge sat18 and act18
satact18_join = pd.merge(act18_rename, sat18_rename, on = 'state')

# %%
satact18_join.shape
# Out:
# (51, 11)

# %%
satact18_join.head()
# Out:
#         state  act_2018_participation_percent  act_2018_avg_composite  \
# 0     Alabama                           100.0                    19.1
# 1      Alaska                            33.0                    20.8
# 2     Arizona                            66.0                    19.2
# 3    Arkansas                           100.0                    19.4
# 4  California                            27.0                    22.7
#
#    act_2018_avg_english  act_2018_avg_math  act_2018_avg_reading  \
# 0                  18.9               18.3                  19.6
# 1                  19.8               20.6                  21.6
# 2                  18.2               19.4                  19.5
# 3                  19.1               18.9                  19.7
# 4                  22.5               22.5                  23.0
#
#    act_2018_avg_science  sat_2018_participation_percent  sat_2018_erw  \
# 0                  19.0                             6.0           595
# ...

# %%
# merge sat & act 2017 combined data with sat & act 2018 data
final = pd.merge(combined_2017, satact18_join, on = 'state')

# %%
final.shape
# Out:
# (51, 21)

# %%
#export final as the final combined file
final.to_csv('final.csv', index = False)

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Code:
final.describe().transpose()
# Out:
#                                 count         mean        std    min      25%  \
# act_2017_participation_percent   51.0    65.254902  32.140842    8.0    31.00
# act_2017_avg_english             51.0    20.931373   2.353677   16.3    19.00
# act_2017_avg_math                51.0    21.182353   1.981989   18.0    19.40
# act_2017_avg_reading             51.0    22.013725   2.067271   18.1    20.45
# act_2017_avg_science             51.0    21.041176   3.182463    2.3    19.90
# act_2017_avg_composite           51.0    21.519608   2.020695   17.8    19.80
# sat_2017_participation_percent   51.0    39.803922  35.276632    2.0     4.00
# sat_2017_erw                     51.0   569.117647  45.666901  482.0   533.50
# sat_2017_math                    51.0   547.627451  84.909119   52.0   522.00
# sat_2017_total                   51.0  1126.098039  92.494812  950.0  1055.50
# act_2018_participation_percent   51.0    61.647059  34.080976    7.0    28.50
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#code
def std_dev(num):
    
    total = sum(num)
    mean = total / len(num)
    sum_of_sq = sum( [(a - mean)**2 for a in num] )
    return (sum_of_sq / len(num))**0.5

# %%
# test function
std_dev(final.act_2017_avg_math)
# Out:
# 1.9624620273436781

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
# each column is key
# standard deviation is the value
sd = {col:round(std_dev(final[col]),4) for col in final.columns[1:] }

# %%
sd
# Out:
# {'act_2017_participation_percent': 31.8242,
#  'act_2017_avg_english': 2.3305,
#  'act_2017_avg_math': 1.9625,
#  'act_2017_avg_reading': 2.0469,
#  'act_2017_avg_science': 3.1511,
#  'act_2017_avg_composite': 2.0008,
#  'sat_2017_participation_percent': 34.9291,
#  'sat_2017_erw': 45.217,
#  'sat_2017_math': 84.0726,
#  'sat_2017_total': 91.5835,
#  'act_2018_participation_percent': 33.7452,
#  'act_2018_avg_composite': 2.0855,
#  'act_2018_avg_english': 2.4223,
#  'act_2018_avg_math': 2.0157,
#  'act_2018_avg_reading': 2.1459,
#  'act_2018_avg_science': 1.8517,
#  'sat_2018_participation_percent': 36.9466,
#  'sat_2018_erw': 47.0346,
#  'sat_2018_math': 47.3019,
#  'sat_2018_total': 93.2274}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %%
final.describe()
# Out:
#        act_2017_participation_percent  act_2017_avg_english  \
# count                       51.000000             51.000000
# mean                        65.254902             20.931373
# std                         32.140842              2.353677
# min                          8.000000             16.300000
# 25%                         31.000000             19.000000
# 50%                         69.000000             20.700000
# 75%                        100.000000             23.300000
# max                        100.000000             25.500000
#
#        act_2017_avg_math  act_2017_avg_reading  act_2017_avg_science  \
# count          51.000000             51.000000             51.000000
# mean           21.182353             22.013725             21.041176
# std             1.981989              2.067271              3.182463
# min            18.000000             18.100000              2.300000
# 25%            19.400000             20.450000             19.900000
# ...

# %%
round(np.std(final),4)
# Out:
# act_2017_participation_percent    31.8242
# act_2017_avg_english               2.3305
# act_2017_avg_math                  1.9625
# act_2017_avg_reading               2.0469
# act_2017_avg_science               3.1511
# act_2017_avg_composite             2.0008
# sat_2017_participation_percent    34.9291
# sat_2017_erw                      45.2170
# sat_2017_math                     84.0726
# sat_2017_total                    91.5835
# act_2018_participation_percent    33.7452
# act_2018_avg_composite             2.0855
# act_2018_avg_english               2.4223
# act_2018_avg_math                  2.0157
# act_2018_avg_reading               2.1459
# act_2018_avg_science               1.8517
# sat_2018_participation_percent    36.9466
# sat_2018_erw                      47.0346
# sat_2018_math                     47.3019
# sat_2018_total                    93.2274
# dtype: float64

# %% [markdown]
# #### Answer
#
# My manually calculated standard deviations using std_dev function does not match up with the output from pandas describe() function.
#
# My calculated standard deviations matches with numpy's std method.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# ### States with highest participation rate for 2017 SAT

# %%
final[["sat_2017_participation_percent", "state"]].sort_values(by = "sat_2017_participation_percent", ascending = False).head(5)
# Out:
#     sat_2017_participation_percent                 state
# 8                            100.0  District of Columbia
# 22                           100.0              Michigan
# 6                            100.0           Connecticut
# 7                            100.0              Delaware
# 29                            96.0         New Hampshire

# %% [markdown]
# ### States with lowest participation rate for 2017 SAT

# %%
final[["sat_2017_participation_percent", "state"]].sort_values(by = "sat_2017_participation_percent", ascending = True).head(5)
# Out:
#     sat_2017_participation_percent         state
# 34                             2.0  North Dakota
# 24                             2.0   Mississippi
# 15                             2.0          Iowa
# 25                             3.0      Missouri
# 44                             3.0          Utah

# %% [markdown]
# ### States with highest participation rate for 2018 SAT

# %%
final[["sat_2018_participation_percent", "state"]].sort_values(by = "sat_2018_participation_percent", ascending = False).head(5)
# Out:
#     sat_2018_participation_percent        state
# 5                            100.0     Colorado
# 6                            100.0  Connecticut
# 7                            100.0     Delaware
# 22                           100.0     Michigan
# 12                           100.0        Idaho

# %% [markdown]
# ### States with lowest participation rate for 2018 SAT

# %%
final[["sat_2018_participation_percent", "state"]].sort_values(by = "sat_2018_participation_percent", ascending = True).head(5)
# Out:
#     sat_2018_participation_percent         state
# 34                             2.0  North Dakota
# 50                             3.0       Wyoming
# 41                             3.0  South Dakota
# 27                             3.0      Nebraska
# 49                             3.0     Wisconsin

# %% [markdown]
# ### States with highest participation rate for 2017 ACT

# %%
final[["act_2017_participation_percent", "state"]].sort_values(by = "act_2017_participation_percent", ascending = False).head(5)
# Out:
#     act_2017_participation_percent      state
# 0                            100.0    Alabama
# 17                           100.0   Kentucky
# 49                           100.0  Wisconsin
# 44                           100.0       Utah
# 42                           100.0  Tennessee

# %% [markdown]
# ### States with lowest participation rate for 2017 ACT

# %%
final[["act_2017_participation_percent", "state"]].sort_values(by = "act_2017_participation_percent", ascending = True).head(5)
# Out:
#     act_2017_participation_percent          state
# 19                             8.0          Maine
# 29                            18.0  New Hampshire
# 7                             18.0       Delaware
# 39                            21.0   Rhode Island
# 38                            23.0   Pennsylvania

# %% [markdown]
# ### States with highest participation rate for 2018 ACT

# %%
final[["act_2018_participation_percent", "state"]].sort_values(by = "act_2018_participation_percent", ascending = False).head(5)
# Out:
#     act_2018_participation_percent      state
# 0                            100.0    Alabama
# 17                           100.0   Kentucky
# 49                           100.0  Wisconsin
# 44                           100.0       Utah
# 42                           100.0  Tennessee

# %% [markdown]
# ### States with lowest participation rate for 2018 ACT

# %%
final[["act_2018_participation_percent", "state"]].sort_values(by = "act_2018_participation_percent", ascending = True).head(5)
# Out:
#     act_2018_participation_percent          state
# 19                             7.0          Maine
# 39                            15.0   Rhode Island
# 29                            16.0  New Hampshire
# 7                             17.0       Delaware
# 38                            20.0   Pennsylvania

# %% [markdown]
# ### States with highest mean score for 2017 SAT

# %%
final[["sat_2017_total", "state"]].sort_values(by = "sat_2017_total", ascending = False).head(5)
# Out:
#     sat_2017_total      state
# 23            1295  Minnesota
# 49            1291  Wisconsin
# 15            1275       Iowa
# 25            1271   Missouri
# 16            1260     Kansas

# %% [markdown]
# ### States with lowest mean score for 2017 SAT

# %%
final[["sat_2017_total", "state"]].sort_values(by = "sat_2017_total", ascending = True).head(5)
# Out:
#     sat_2017_total                 state
# 8              950  District of Columbia
# 7              996              Delaware
# 12            1005                 Idaho
# 22            1005              Michigan
# 19            1012                 Maine

# %% [markdown]
# ### States with highest mean Composite score  for 2017 ACT

# %%
final[["act_2017_avg_composite", "state"]].sort_values(by = "act_2017_avg_composite", ascending = False).head(5)
# Out:
#     act_2017_avg_composite                 state
# 29                    25.5         New Hampshire
# 21                    25.4         Massachusetts
# 6                     25.2           Connecticut
# 19                    24.3                 Maine
# 8                     24.2  District of Columbia

# %% [markdown]
# ### States with lowest mean Composite score  for 2017 ACT

# %%
final[["act_2017_avg_composite", "state"]].sort_values(by = "act_2017_avg_composite", ascending = True).head(5)
# Out:
#     act_2017_avg_composite           state
# 28                    17.8          Nevada
# 24                    18.6     Mississippi
# 40                    18.7  South Carolina
# 11                    19.0          Hawaii
# 33                    19.1  North Carolina

# %% [markdown]
# ### States with highest mean score  for 2018 SAT

# %%
final[["sat_2018_total", "state"]].sort_values(by = "sat_2018_total", ascending = False).head(5)
# Out:
#     sat_2018_total         state
# 23            1298     Minnesota
# 49            1294     Wisconsin
# 34            1283  North Dakota
# 15            1265          Iowa
# 16            1265        Kansas

# %% [markdown]
# ### States with lowest mean score  for 2018 SAT

# %%
final[["sat_2018_total", "state"]].sort_values(by = "sat_2018_total", ascending = True).head(5)
# Out:
#     sat_2018_total                 state
# 8              977  District of Columbia
# 7              998              Delaware
# 48             999         West Virginia
# 12            1001                 Idaho
# 44            1010                  Utah

# %% [markdown]
# ### States with highest mean Composite score  for 2018 ACT

# %%
final[["act_2018_avg_composite", "state"]].sort_values(by = "act_2018_avg_composite", ascending = False).head(5)
# Out:
#     act_2018_avg_composite          state
# 6                     25.6    Connecticut
# 21                    25.5  Massachusetts
# 29                    25.1  New Hampshire
# 32                    24.5       New York
# 22                    24.4       Michigan

# %% [markdown]
# ### States with lowest mean Composite score  for 2018 ACT

# %%
final[["act_2018_avg_composite", "state"]].sort_values(by = "act_2018_avg_composite", ascending = True).head(5)
# Out:
#     act_2018_avg_composite           state
# 28                    17.7          Nevada
# 40                    18.3  South Carolina
# 24                    18.6     Mississippi
# 11                    18.9          Hawaii
# 0                     19.1         Alabama

# %% [markdown]
# ### Do any states with 100% participation on a given test have a rate change year-to-year?

# %% [markdown]
# ### States with *100% participation* and *no changes* in participation rate for SAT in 2017 & 2018

# %%
# add a new column 'change' in dataframe to visualize changes in SAT 2017 and 2018 better.
final['sat_change'] = final["sat_2017_participation_percent"]-final["sat_2018_participation_percent"]

# filter on change
final[(final["sat_2017_participation_percent"] == 100) &\
      (final["sat_2018_participation_percent"] == 100) &\
      (final["sat_change"] == 0)]\
     [["state","sat_2017_participation_percent",
       "sat_2018_participation_percent",
       "sat_change"]]\
        .sort_values(by = "sat_change",ascending = False)
# Out:
#           state  sat_2017_participation_percent  \
# 6   Connecticut                           100.0
# 7      Delaware                           100.0
# 22     Michigan                           100.0
#
#     sat_2018_participation_percent  sat_change
# 6                            100.0         0.0
# 7                            100.0         0.0
# 22                           100.0         0.0

# %% [markdown]
# ### States with *100% participation* and *changes* in participation rate for SAT in 2017 & 2018

# %% [markdown]
# ### There are no changes in participation rate!

# %%
# filter on change
final[(final["sat_2017_participation_percent"] == 100) &\
      (final["sat_2018_participation_percent"] == 100) &\
      (final["sat_change"] != 0)]\
     [["state","sat_2017_participation_percent",
       "sat_2018_participation_percent",
       "sat_change"]]\
        .sort_values(by = "sat_change",ascending = False)
# Out:
# Empty DataFrame
# Columns: [state, sat_2017_participation_percent, sat_2018_participation_percent, sat_change]
# Index: []

# %% [markdown]
# ### States with *100% participation* and *no changes* in participation rate for ACT in 2017 & 2018

# %%
# add a new column 'change' in dataframe to visualize changes in ACT 2017 and 2018 better.
final['act_change'] = final["act_2017_participation_percent"]-final["act_2018_participation_percent"]

# filter on change
final[(final["act_2017_participation_percent"] == 100) &\
      (final["act_2018_participation_percent"] == 100) &\
      (final["act_change"] == 0)]\
     [["state","act_2017_participation_percent",
       "act_2018_participation_percent",
       "act_change"]]\
        .sort_values(by = "act_change",ascending = False)
# Out:
#              state  act_2017_participation_percent  \
# 0          Alabama                           100.0
# 3         Arkansas                           100.0
# 17        Kentucky                           100.0
# 18       Louisiana                           100.0
# 24     Mississippi                           100.0
# 25        Missouri                           100.0
# 26         Montana                           100.0
# 28          Nevada                           100.0
# 33  North Carolina                           100.0
# 36        Oklahoma                           100.0
# 40  South Carolina                           100.0
# 42       Tennessee                           100.0
# 44            Utah                           100.0
# 49       Wisconsin                           100.0
# 50         Wyoming                           100.0
#
#     act_2018_participation_percent  act_change
# 0                            100.0         0.0
# 3                            100.0         0.0
# ...

# %% [markdown]
# ### States with *100% participation* and *changes* in participation rate for ACT in 2017 & 2018

# %% [markdown]
# ### There are no changes in participation rate!

# %%
# filter on change
final[(final["act_2017_participation_percent"] == 100) &\
      (final["act_2018_participation_percent"] == 100) &\
      (final["act_change"] != 0)]\
     [["state","act_2017_participation_percent",
       "act_2018_participation_percent",
       "act_change"]]\
        .sort_values(by = "act_change",ascending = False)
# Out:
# Empty DataFrame
# Columns: [state, act_2017_participation_percent, act_2018_participation_percent, act_change]
# Index: []

# %% [markdown]
# ### Do any states show have >50% participation on both tests either year?
#
# ### 2017: Florida, Georgia, Hawaii
# ### 2018: Florida, Georgia, Hawaii, South Carolina, North Carolina

# %% [markdown]
# ### States > 50% participation for SAT & ACT in 2017.

# %%
# filter for states with more than 50% participation in SAT and ACT 2017

final[(final["sat_2017_participation_percent"] > 50) &\
      (final["act_2017_participation_percent"] > 50) ]\
      [['state',"sat_2017_participation_percent",'act_2017_participation_percent']].\
      sort_values(by = "sat_2017_participation_percent", ascending = False)
# Out:
#       state  sat_2017_participation_percent  act_2017_participation_percent
# 9   Florida                            83.0                            73.0
# 10  Georgia                            61.0                            55.0
# 11   Hawaii                            55.0                            90.0

# %% [markdown]
# ### States > 50% participation for SAT & ACT in 2018.

# %%
# filter for states with more than 50% participation in SAT and ACT 2018

final[(final["sat_2018_participation_percent"] > 50) &\
      (final["act_2018_participation_percent"] > 50) ]\
      [['state',"sat_2018_participation_percent",'act_2018_participation_percent']].\
      sort_values(by = "sat_2018_participation_percent", ascending = False)
# Out:
#              state  sat_2018_participation_percent  \
# 10         Georgia                            70.0
# 9          Florida                            56.0
# 11          Hawaii                            56.0
# 40  South Carolina                            55.0
# 33  North Carolina                            52.0
#
#     act_2018_participation_percent
# 10                            53.0
# 9                             66.0
# 11                            89.0
# 40                           100.0
# 33                           100.0

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
# drop change columns
final = final.drop(columns = ['sat_change','act_change'])
final.columns
# Out:
# Index(['state', 'act_2017_participation_percent', 'act_2017_avg_english',
#        'act_2017_avg_math', 'act_2017_avg_reading', 'act_2017_avg_science',
#        'act_2017_avg_composite', 'sat_2017_participation_percent',
#        'sat_2017_erw', 'sat_2017_math', 'sat_2017_total',
#        'act_2018_participation_percent', 'act_2018_avg_composite',
#        'act_2018_avg_english', 'act_2018_avg_math', 'act_2018_avg_reading',
#        'act_2018_avg_science', 'sat_2018_participation_percent',
#        'sat_2018_erw', 'sat_2018_math', 'sat_2018_total'],
#       dtype='object')

# %%
# apply correlation function on final dataframe
final_corr = final.corr()

# set parameters in matplotlib.pyplot
plt.rcParams['font.size'] = 14
plt.figure(figsize = (20,20))

# generate mask
mask = np.zeros_like(final_corr)
mask[np.triu_indices_from(mask)] = True

# generate heatmap
sns.heatmap(final_corr, annot=True, mask = mask).set_title('Correlation strength between each item in dataset', fontsize=30)
plt.show()

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    
    nrows = int(np.ceil(len(list_of_columns)/2)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (15,15)) # to create specific number of subplots
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): # Gives us an index value to get into all our lists,
                                                 # plots graphs based on number of columns given
        ax[i].hist(x = dataframe[column], bins = 10, histtype = 'bar') # feel free to add more settings
        ax[i].set_xlabel(list_of_xlabels)
        ax[i].set_title(list_of_titles[i], fontsize = 20, fontweight = 'bold')
        # Set titles, labels, etc here for each subplot

# %% [markdown]
# ### Math scores for SAT & ACT

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %% [markdown]
# ### Participation rates for SAT & ACT

# %%
# data for sat and act 2017 and 2018
data_bar = final[['sat_2017_participation_percent','act_2017_participation_percent',\
        'sat_2018_participation_percent','act_2018_participation_percent']]

# %%
# list_of_columns
data_barcol = data_bar.columns

# %%
# list_of_titles
bar_title = ['sat 2017 participation','act 2017 participation','sat 2018 participation','act 2018 participation']

# %%
# list_of_xlabels
bar_x = 'Participation in (%)'

# %%
# Participation rates for SAT and ACT 2017 & 2018
subplot_histograms(data_bar, data_barcol, bar_title, bar_x)

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
from sklearn.linear_model import LinearRegression

def subplot_scatter(dataframe,list_of_columns, list_of_titles):
    
    nrows = int(np.ceil(len(list_of_columns)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=1, figsize = (30,50)) 
    ax = ax.ravel() 
    j = 0
    for i in range(0,len(list_of_columns)-1,2):
        ax[j].scatter(x = dataframe.iloc[:,i], y = dataframe.iloc[:,i+1], color = 'blue')
        ax[j].set_xlabel(dataframe.columns[i].replace('_'," "),fontsize = 15, fontweight = 'bold')
        ax[j].set_ylabel(dataframe.columns[i+1].replace('_'," "),fontsize = 15, fontweight = 'bold')
        ax[j].set_title(list_of_titles[j], fontsize = 25, fontweight = 'bold', color = 'maroon')
        
        # put in the values to generate linear regression model
        model = LinearRegression().fit(pd.DataFrame(dataframe.iloc[:,i]), pd.DataFrame(dataframe.iloc[:,i+1]))
        
        # obtain y-hat value, the y value is obtained after substiting in x values into the linear regression model
        # obtained from LinearRegression(). This will be the y value of the linear regression model
        y_hat = model.predict(pd.DataFrame(dataframe.iloc[:,i]))
        
        ax[j].plot(dataframe.iloc[:,i], y_hat, color = 'crimson')
        j += 1

# %%
# data to plot scatterplots
data_scatter = final[['act_2017_avg_math', 'sat_2017_math',
              'act_2017_avg_reading', 'sat_2017_erw',
              'act_2017_avg_composite', 'sat_2017_total',
              'sat_2017_total','sat_2018_total',
              'act_2017_avg_composite','act_2018_avg_composite']]

# %%
# columns of data_scatter
data_scattercols = data_scatter.columns

# %%
# list of titles
data_scatter_title = ['score of sat_math against score of act_math 2017',
                'score of sat_read against score of act_read 2017',
                'score of sat_total against score of act_composite 2017',
                'score of sat_total 2018 against score of sat_total 2017',
                'score of act_composite 2018 against act_composite 2017']

# %%
subplot_scatter(data_scatter,data_scattercols,data_scatter_title)

# %% [markdown]
# ### In scatterplot of score of sat_math against score of act_math 2017, SAT math score is 52 and ACT math score is 23.1

# %%
# check any SAT math score < 100 and ACT math score > 23 in 2017
final[(final["sat_2017_math"] < 100) & (final["act_2017_avg_math"] > 23) ][['state','sat_2017_math','act_2017_avg_math']]
# Out:
#        state  sat_2017_math  act_2017_avg_math
# 20  Maryland             52               23.1

# %% [markdown]
# ### Check SAT math score in 2017 against 2018

# %%
# check any SAT math scores in 2017 & 2018 < 400
final[(final["sat_2017_math"] < 400) | (final["sat_2018_math"] < 400) ][['state','sat_2017_math','sat_2018_math']]
# Out:
#        state  sat_2017_math  sat_2018_math
# 20  Maryland             52            535

# %% [markdown]
# ### SAT math score of 52 for Maryland may be an input error

# %%
# check the lowest SAT math score in 2017 & 2018
final[['state','sat_2017_math','sat_2018_math']].sort_values(by = 'sat_2017_math', ascending = True).head(5)
# Out:
#                    state  sat_2017_math  sat_2018_math
# 20              Maryland             52            535
# 8   District of Columbia            468            480
# 7               Delaware            492            492
# 12                 Idaho            493            493
# 22              Michigan            495            499

# %% [markdown]
# ### Observations from scatterplots
# a. In score of sat_math against score of act_math 2017, the sat score is in the range of 500 to 600, while the act score is from 18 to 25. The max score for sat_math is 800 and act_math is 36. There is no passing mark for SAT and ACT test. From the line of best fit, it suggests there is a negative correlation. The trend shows that if students do better in act_math do not do better in sat_math. There is the possibility that the sat math is more difficult than the act math.
#
# b. For score of sat_read against score of act_read 2017, score of sat_total against score of act_composite 2017,  the points are far away from line of best fit. This suggests that there is poor correlation between the 2 variables in each plot respectively. The trend shows that if students do better in ACT test do not do better in SAT test. There is the possibility that the SAT test is more difficult than the ACT math.
#
# c. For score of sat_total 2018 against score of sat_total 2017, generally the points are close to the line of best fit. This suggests that there is positive correlation between the 2 variables in each plot respectively. Students that do well in 2017 also do well in 2018.
#
# d. For score of act_composite 2018 against act_composite 2017,  generally the points are close to the line of best fit. This suggests that there is positive correlation between the 2 variables in each plot respectively. Students that do well in 2017 also do well in 2018.

# %% [markdown]
# ### To conclude from the scatter plots:
# 1. SAT is more difficult than ACT based on the trends seen.
#
# 2. Students' scores in 2017 has a positive correlation with scores in 2018. This suggests the students' performance are consistent in this 2 years.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
def subplot_boxplot(dataframe, list_of_columns):
    
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (15,60))
    ax = ax.ravel() 
    for i, column in enumerate(list_of_columns): 
        sns.boxplot(x= dataframe[column], data= dataframe,  orient='v', ax= ax[i])

# %%
# dataset for boxplot
data_boxplot = final.iloc[:,1:]

# %%
# col names
data_boxplotcols = data_boxplot.columns

# %%
subplot_boxplot(data_boxplot, data_boxplotcols)

# %% [markdown]
# ### ACT 2017 science score summary

# %%
final.act_2017_avg_science.describe()
# Out:
# count    51.000000
# mean     21.041176
# std       3.182463
# min       2.300000
# 25%      19.900000
# 50%      21.300000
# 75%      22.750000
# max      24.900000
# Name: act_2017_avg_science, dtype: float64

# %% [markdown]
# ##### Check which state in ACT 2017 science has score of 2.3

# %%
final[final['act_2017_avg_science'] == 2.3][['state']]
# Out:
#        state
# 20  Maryland

# %% [markdown]
# ##### ACT 2017 scores for Maryland is consistent

# %%
final[final['state'] == 'Maryland'][['state','act_2017_avg_english','act_2017_avg_math','act_2017_avg_reading','act_2017_avg_science']]
# Out:
#        state  act_2017_avg_english  act_2017_avg_math  act_2017_avg_reading  \
# 20  Maryland                  23.3               23.1                  24.2
#
#     act_2017_avg_science
# 20                   2.3

# %% [markdown]
# #### ACT science score of 2.3 be due to input error.

# %% [markdown]
# ### SAT 2017 math score summary

# %%
final.sat_2017_math.describe()
# Out:
# count     51.000000
# mean     547.627451
# std       84.909119
# min       52.000000
# 25%      522.000000
# 50%      548.000000
# 75%      599.000000
# max      651.000000
# Name: sat_2017_math, dtype: float64

# %% [markdown]
# ##### SAT 2017 & 2018 scores for Maryland is consistent

# %%
final[final['state'] == 'Maryland'][['state','sat_2017_erw','sat_2017_math','sat_2017_total','sat_2018_erw','sat_2018_math','sat_2018_total']]
# Out:
#        state  sat_2017_erw  sat_2017_math  sat_2017_total  sat_2018_erw  \
# 20  Maryland           536             52            1060           545
#
#     sat_2018_math  sat_2018_total
# 20            535            1080

# %% [markdown]
# ##### Summary of participation rates of SAT and ACT in 2017 & 2018

# %%
final[['act_2017_participation_percent','act_2018_participation_percent','sat_2017_participation_percent','sat_2018_participation_percent']].describe()
# Out:
#        act_2017_participation_percent  act_2018_participation_percent  \
# count                       51.000000                       51.000000
# mean                        65.254902                       61.647059
# std                         32.140842                       34.080976
# min                          8.000000                        7.000000
# 25%                         31.000000                       28.500000
# 50%                         69.000000                       66.000000
# 75%                        100.000000                      100.000000
# max                        100.000000                      100.000000
#
#        sat_2017_participation_percent  sat_2018_participation_percent
# count                       51.000000                       51.000000
# mean                        39.803922                       45.745098
# std                         35.276632                       37.314256
# ...

# %% [markdown]
# ##### Summary of  composite and total scores of SAT and ACT in 2017 & 2018

# %%
final[['act_2017_avg_composite','act_2018_avg_composite','sat_2017_total','sat_2018_total']].describe()
# Out:
#        act_2017_avg_composite  act_2018_avg_composite  sat_2017_total  \
# count               51.000000               51.000000       51.000000
# mean                21.519608               21.486275     1126.098039
# std                  2.020695                2.106278       92.494812
# min                 17.800000               17.700000      950.000000
# 25%                 19.800000               19.950000     1055.500000
# 50%                 21.400000               21.300000     1107.000000
# 75%                 23.600000               23.550000     1212.000000
# max                 25.500000               25.600000     1295.000000
#
#        sat_2018_total
# count       51.000000
# mean      1120.019608
# std         94.155083
# min        977.000000
# 25%       1057.500000
# 50%       1098.000000
# 75%       1204.000000
# max       1298.000000

# %% [markdown]
# ## Observations from boxplot
#
# #### 1) ACT 2017 science
# The students seem to be doing well for science in ACT test 2017, as seen from the box plot the spread of scores is small. The mean score is 21, which is 58.3% against the max score of 800. The outlier of 2.3 may be due to input error.
#
# https://blog.prepscholar.com/historical-act-percentiles-2019-2018-2017-2016-2015
# Based on the historical data from the website above, there is 1% of the students scoring below 3 for ACT 2017 science score. The average ACT scores for all the subjects in Maryland is between 23.3 to 24.2 except science, which is 2.3. Hence, the score is highly unlikely, and may be input error.
#
# #### 2) SAT 2017 math
# The students seem to be doing well for math in SAT test 2017. The mean score is 547, which is 68.3% against the max score of 800. The outlier, which is score of 52 from Maryland, may be due to input error, as mentioned previously.
#
# https://blog.prepscholar.com/historical-percentiles-new-sat
# Based on the historical data from the website above, there is -1% of the students scoring below 250 for SAT 2017 science score. Hence, the score is highly unlikely, and may be input error.
#
# #### 3) participation rates of SAT and ACT in 2017 & 2018
# The participation rate of ACT is higher than SAT in 2017 and 2018. It can be seen at the 75th percentile, the participation rate of ACT is 100% for both years. The participation rate of SAT is 66% in 2017 and 77.5% in 2018. This shows that students prefer to take ACT over SAT. Also, the mean participation rate of ACT is higher than that of SAT for both 2017 and 2018.
#
# #### 4) composite and total scores of SAT and ACT in 2017 & 2018
# The mean of composite scores is 21 in ACT 2017 and 2018. The mean of total scores is 1126 and 1120 in SAT 2017 and 2018 respectively. For ACT, it is 58.3% against the total of 36. For SAT (1126+1120/1600), it is 70.2% against the total of 1600.
# Generally, students score better in ACT than SAT, hence students may prefer to take SAT over ACT. This is as reflected in the participation rates also.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %% [markdown]
# ### Summary of final data

# %%
final.describe()
# Out:
#        act_2017_participation_percent  act_2017_avg_english  \
# count                       51.000000             51.000000
# mean                        65.254902             20.931373
# std                         32.140842              2.353677
# min                          8.000000             16.300000
# 25%                         31.000000             19.000000
# 50%                         69.000000             20.700000
# 75%                        100.000000             23.300000
# max                        100.000000             25.500000
#
#        act_2017_avg_math  act_2017_avg_reading  act_2017_avg_science  \
# count          51.000000             51.000000             51.000000
# mean           21.182353             22.013725             21.041176
# std             1.981989              2.067271              3.182463
# min            18.000000             18.100000              2.300000
# 25%            19.400000             20.450000             19.900000
# ...

# %% [markdown]
# ### Answers:
#
# Mean: It is the average score of the subject. All the states' score for the subject is summed and divided by the number of
# states. Effectively, this also gives us the national average score for the subject.
#
# Std: It is the standard deviation. It shows what is the average of the difference of each score in the state against the mean.
# This shows the national performance in the subject. If the std is large, students may score below the 25th percentile and 75th percentile. It means the proficiency level of the students in the subject on the national level is not consistent.
#
# min: Minimum value of the variable. It translates to the minimum national score.
#
# 25%: 25th percentile. It shows what is the national score at the 25th percentile in the subject. For example, for act 2017
# English score, 25% of the students scored 19 points.
#
# 50% 50th percentile. It shows what is the national score at the 50th percentile in the subject. For example, for act 2017
# English score, 50% of the students scored 20.7 points.
#
# 75% 75th percentile. It shows what is the national score at the 75th percentile in the subject. For example, for act 2017
# English score, 75% of the students scored 23.3 points.
#
# max: Maximum value of the variable. It translates to the maximum national score, which is the highest score achieved on the
# national level.

# %% [markdown]
# #### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %% [markdown]
# ### Answer:
# The mean for the total score of all the states in each subject is the national average. Unless the mean for the total score is resampled for at least 3 times, it will not result in normal distribution. However, if it is resampled for 3 or more times, the mean for the total score will follow a normal distribution, according to central limit theorem.
#
# #### Using ACT math test as the example:
# Population: test results of all the students who have taken the test, for all the USA states listed.
#
# 2017 ACT math test: population mean = 21.182353, national mean act math score is approximately 21
#
# 2018 ACT math test: population mean = 21.125490, national mean act math score is approximately 21
#
# 1) Data acquired for each state is the average score for that state.
#
# 2) There are 51 states, a total of 51 means.
#
# 3) Population data is a population of means.

# %% [markdown]
# #### Example to show that the distribution is not normal

# %%
act_math_2017 = final['act_2017_avg_math']

fig, ax = plt.subplots(figsize=(8,8))
ax.set_title('act 2017 for math', fontsize = 20, fontweight = 'bold')
ax.set_ylabel('percentage of states with the avg act score')
sns.distplot(act_math_2017, bins=50, kde=True, color = 'blue', axlabel = 'act math 2017');

# %%
def sampler (data, n, iteration):
    
    sample = [np.mean(np.random.choice(data, size = n)) for x in range(iteration)]
    return sample

# %%
# using act 2017 math data, re-sample through different number of iterations, to get a population of national 
# mean scores 
sample_10 = sampler (act_math_2017, n = 30, iteration = 10)

# %%
# Plot simulated data, when there is 10 samplings only
fig, ax = plt.subplots(figsize=(4,4))
sns.distplot(sample_10, kde=True);

# %%
#100 iterations
sample_100 = sampler (act_math_2017, n = 30, iteration = 100)

# %%
# Plot simulated data, when there are 100 samplings
fig, ax = plt.subplots(figsize=(4,4))
sns.distplot(sample_100, bins=50, kde=True);

# %%
#10000 iterations
sample_10000 = sampler (act_math_2017, n = 30, iteration = 10000)

# %%
# Plot simulated data, when there are 10000 samplings
fig, ax = plt.subplots(figsize=(4,4))
sns.distplot(sample_10000, bins=50, kde=True);

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %% [markdown]
# ## Plot the graphs for each datasets to see the distributions

# %%
def subplot(dataframe, list_of_columns):
    
    nrows = int(np.ceil(len(list_of_columns)/2)) 
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize = (15,60)) 
    ax = ax.ravel() 
    for i, column in enumerate(list_of_columns): 
                                                 
        ax[i].set_ylabel('Frequency', fontsize = 15, fontweight = 'bold')
        ax[i].set_title(column, fontsize = 20, fontweight = 'bold')
        sns.distplot(dataframe[column], bins=50, kde=True, color = 'blue', ax = ax[i])

# %%
data = final[['act_2017_avg_math','act_2018_avg_math',
             'sat_2017_math', 'sat_2018_math',
             'act_2017_avg_reading', 'act_2018_avg_reading',
             'sat_2017_erw','sat_2018_erw',
             'act_2017_participation_percent', 'act_2018_participation_percent',
             'sat_2017_participation_percent', 'sat_2018_participation_percent']]

list_col = data.columns

# %% [markdown]
# ## Graphs to see distributions

# %%
subplot(data, list_col)

# %% [markdown]
# ## Sample SAT 2018 math, reading and participation rate datasets, 100 iterations

# %%
# create simulated data of 100 iterations
sat_math_2018 = final['sat_2018_math']
sat_erw_2018 = final['sat_2018_erw']
sat_rates_2018 = final['sat_2018_participation_percent']

sample_100_2018math = sampler (sat_math_2018, n = 30, iteration = 100)
sample_100_2018read = sampler (sat_erw_2018, n = 30, iteration = 100)
sample_100_rates = sampler (sat_rates_2018, n = 30, iteration = 100)

# %%
# plot graphs of 100 iterations
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize= (20,20))
ax[0].set_ylabel('Frequency', fontsize = 15, fontweight = 'bold')

ax[0].set_title('sample 2018 math SAT', fontsize = 20, fontweight = 'bold')
ax[1].set_title('sample 2018 read SAT', fontsize = 20, fontweight = 'bold')
ax[2].set_title('sample 2018 part_rates SAT', fontsize = 20, fontweight = 'bold')

sns.distplot(sample_100_2018math, kde=True, ax = ax[0]);
sns.distplot(sample_100_2018read, kde=True, ax = ax[1]);
sns.distplot(sample_100_rates, kde=True, ax = ax[2]);

# %% [markdown]
# ## Sample SAT 2018 math, reading and participation rate datasets, 10000 iterations

# %%
# create simulated data of 10000 iterations
sat_math_2018 = final['sat_2018_math']
sat_erw_2018 = final['sat_2018_erw']
sat_rates_2018 = final['sat_2018_participation_percent']

sample_10000_2018math = sampler (sat_math_2018, n = 30, iteration = 10000)
sample_10000_2018read = sampler (sat_erw_2018, n = 30, iteration = 10000)
sample_10000_rates = sampler (sat_rates_2018, n = 30, iteration = 10000)

# %%
# plot graphs of 10000 iterations
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize= (20,20))
ax[0].set_ylabel('Frequency', fontsize = 15, fontweight = 'bold')

ax[0].set_title('sample 2018 math SAT', fontsize = 20, fontweight = 'bold')
ax[1].set_title('sample 2018 read SAT', fontsize = 20, fontweight = 'bold')
ax[2].set_title('sample 2018 part_rates SAT', fontsize = 20, fontweight = 'bold')

sns.distplot(sample_10000_2018math, kde=True, ax = ax[0]);
sns.distplot(sample_10000_2018read, kde=True, ax = ax[1]);
sns.distplot(sample_10000_rates, kde=True, ax = ax[2]);

# %% [markdown]
# ## Sample ACT 2018 math, reading and participation rate datasets, 10000 iterations

# %%
# create simulated data of 10000 iterations for act_math, act_read, act_participation 2018

act_math_2018 = final['act_2018_avg_math']
act_read_2018 = final['act_2018_avg_reading']
act_rates_2018 = final['act_2018_participation_percent']

sample_10000_2018math_act = sampler (act_math_2018, n = 30, iteration = 10000)
sample_10000_2018read_act = sampler (act_read_2018, n = 30, iteration = 10000)
sample_10000_rates_act = sampler (act_rates_2018, n = 30, iteration = 10000)

# %%
# plot graphs of 10000 iterations
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize= (20,20))
ax[0].set_ylabel('Frequency', fontsize = 15, fontweight = 'bold')

ax[0].set_title('act_2018_avg_math', fontsize = 20, fontweight = 'bold')
ax[1].set_title('act_2018_avg_reading', fontsize = 20, fontweight = 'bold')
ax[2].set_title('act_2018_participation_percent', fontsize = 20, fontweight = 'bold')

sns.distplot(sample_10000_2018math_act, kde=True, ax = ax[0]);
sns.distplot(sample_10000_2018read_act, kde=True, ax = ax[1]);
sns.distplot(sample_10000_rates_act, kde=True, ax = ax[2]);

# %% [markdown]
# ### Answer:
#
# From the simulations and tests above, when the sample size is 30, the distribution of the population of means will be normally distributed. To recap, The population mean is the national mean score for the subject. This shows the central limit theorem. Even when the sample size is small, with repeated sampling, the population of means will be normally distributed.

# %%
# adjust sample size to n = 1, iterations = 10000
sample = sampler (act_math_2017, n = 1, iteration = 10000)

# %%
# Plot simulated data, when there are 10000 samplings
fig, ax = plt.subplots(figsize=(4,4))
sns.distplot(sample, bins=50, kde=True);

# %%
# adjust sample size to n = 3, iterations = 10000
sample = sampler (act_math_2017, n = 3, iteration = 10000)

# %%
# Plot simulated data, when there are 10000 samplings
fig, ax = plt.subplots(figsize=(4,4))
sns.distplot(sample, bins=50, kde=True);

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %%
# Scatterplot of SAT and ACT 2017 participation rates
fig, ax = plt.subplots(figsize=(4,4))

model = LinearRegression().fit(pd.DataFrame(final['sat_2017_participation_percent']), pd.DataFrame(final['act_2017_participation_percent']))
y_hat = model.predict(pd.DataFrame(final['sat_2017_participation_percent']))
        
plt.plot(final['sat_2017_participation_percent'], y_hat, color = 'crimson')
plt.scatter(x = final['sat_2017_participation_percent'], y = final['act_2017_participation_percent'], color = 'blue')
plt.xlabel('sat 2017 participation')
plt.ylabel('act 2017 participation')
plt.show()

# %% [markdown]
# ## Answer:

# %% [markdown]
# Using the example of looking at the relationship of act 2017 participation rates and sat 2017 participation rates, it does not make sense to just look at the relationship.
#
# In the scatter plot above, it suggests a negative correlation between the 2 variables. It seems that when the ACT participation is high, the SAT participation is low, vice versa.
#
# However, when we look at more information and refer to more information sources and contexts, it may explain and make sense of the relationship.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %%
# data
data_scatter = final[['act_2017_avg_math', 'sat_2017_math',
              'act_2018_avg_math', 'sat_2018_math']]

# columns of data_scatter
data_scattercols = data_scatter.columns

# list of titles
data_scatter_title = ['sat_2017_math against act_2017_avg_math',
                      'sat_2018_math against act_2018_avg_math']

subplot_scatter(data_scatter, data_scattercols, data_scatter_title)

# %% [markdown]
# ## Answer:
#
# No, it will be inappropriate. Based on the graphs above, even if a student has a higher score in ACT, the student may have a lower score in SAT. Looking at the trend, it seems that there is a negative correlation between SAT and ACT score. The SAT test may be more difficult than the ACT test. The marking standards for SAT test may be higher, hence increasing the difficulty of scoring.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# #### States that have >50% participation on both tests either year
#
# #### 2017: Florida, Georgia, Hawaii
# #### 2018: Florida, Georgia, Hawaii, South Carolina, North Carolina

# %% [markdown]
# ![sat_act2017.PNG](attachment:sat_act2017.PNG)
# ![sat_act2018.PNG](attachment:sat_act2018.PNG)

# %% [markdown]
# ##  Florida, Georgia, Hawaii
#
# #### Florida
# In Florida, there is a college scholarship which are attractive to students. The students must submit their SAT or ACT scores to complete the application. This may explain why the SAT and ACT participation rates are high in Florida.
#
# https://www.floridastudentfinancialaidsg.org/PDF/BFHandbookChapter1.pdf
#
# #### Georgia
# Citing a similar case in Georgia, students will need to submit their SAT or ACT scores to qualify for scholarship
# ![image.png](attachment:image.png)
#
# https://www.ajc.com/education/georgia-colleges-waive-satact-requirements-for-upcoming-admissions/5ZCA2ILIRVE57C7AP6NIGQB7XY/
#
# ### Hawaii
# For Hawaii, the scholarships seem to base more on GPA than SAT or ACT scores. More in-depth search has to be done to find a plausible explaination for the high ACT and SAT participation rates.
#
# http://www.collegescholarships.org/grants/states/hawaii.htm

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# ##### 1. SAT is more difficult than ACT based on the trends seen.
#
# ##### 2. Students' scores in 2017 has a positive correlation with scores in 2018. This suggests the students' performance are consistent in this 2 years.
#
# ##### 3. Review the standard for SAT test and ACT test, if the difficulty matches the participation rates may even out.
